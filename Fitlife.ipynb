# %%
import pandas as pd

df = pd.read_csv(r"\\ad.wayne.edu\Users\ex4360\Documents\Health fitness\health_fitness_dataset.csv")
df.head()
# Out:
#    participant_id      date  age gender  height_cm  weight_kg  \
# 0               1  1/1/2024   56      F      165.3       53.7
# 1               1  1/4/2024   56      F      165.3       53.9
# 2               1  1/5/2024   56      F      165.3       54.2
# 3               1  1/7/2024   56      F      165.3       54.4
# 4               1  1/9/2024   56      F      165.3       54.7
#
#      activity_type  duration_minutes intensity  calories_burned  ...  \
# 0          Dancing                41       Low              3.3  ...
# 1         Swimming                28       Low              2.9  ...
# 2         Swimming                21    Medium              2.6  ...
# 3  Weight Training                99    Medium             10.7  ...
# 4         Swimming               100    Medium             12.7  ...
#
#    stress_level  daily_steps  hydration_level   bmi  resting_heart_rate  \
# 0             3         7128              1.5  19.6                69.5
# ...

# %%
#Do people who take more steps burn more calories?

print(df[["daily_steps", "calories_burned"]].corr())

import matplotlib.pyplot as plt
plt.scatter(df["daily_steps"], df["calories_burned"], alpha=0.2)
plt.xlabel("Daily Steps")
plt.ylabel("Calories Burned")
plt.title("Steps vs Calories Burned")
plt.show()
# Out:
#                  daily_steps  calories_burned
# daily_steps         1.000000        -0.126245
# calories_burned    -0.126245         1.000000

# %%
# Is there a link between sleep hours and activity levels?

print(df[["hours_sleep", "daily_steps"]].corr())

plt.scatter(df["hours_sleep"], df["daily_steps"], alpha=0.2)
plt.xlabel("Hours of Sleep")
plt.ylabel("Daily Steps")
plt.title("Sleep vs Activity")
plt.show()
# Out:
#              hours_sleep  daily_steps
# hours_sleep     1.000000     0.001025
# daily_steps     0.001025     1.000000

# %%
#Which days have the highest average activity
df["date"] = pd.to_datetime(df["date"])
df["weekday"] = df["date"].dt.day_name()

avg_steps_by_day = df.groupby("weekday")["daily_steps"].mean().sort_values(ascending=False)
print(avg_steps_by_day)

avg_steps_by_day.plot(kind="bar", title="Average Steps by Day of Week")
plt.ylabel("Steps")
plt.show()
# Out:
# weekday
# Saturday     9808.786483
# Sunday       9798.232644
# Thursday     8171.063059
# Monday       8170.277135
# Friday       8165.202648
# Wednesday    8158.610159
# Tuesday      8154.929655
# Name: daily_steps, dtype: float64
